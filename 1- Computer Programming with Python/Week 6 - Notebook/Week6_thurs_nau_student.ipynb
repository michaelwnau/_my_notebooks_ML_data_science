# %% [markdown]
# # Workshop 6 [Student]
#
# This notebook will cover the following topics:
#
# 1. Graphs
# 2. Trees
# 4. Binary Trees
# 5. Traversals
# 6. Searching
#     - BFS
#     - DFS

# %% [markdown]
# ## 6.1 GRAPHS AND TREES (NETWORKX) (Follow)
#
# **Learning Objectives:**
#
# 1. Understand the structure of graphs.
# 2. Understand how to create graphs.
# 3. Understand the network X library in python.
# 4. Learn to use network X

# %%
pip install networkx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
"""
Add comments for you own reference

Code Reference: 
https://networkx.org/documentation/stable/reference/introduction.html
"""
import numpy
numpy.random.seed(42)

import networkx as nx

G = nx.Graph()
G.add_node(1)
G.add_node(2)
G.add_nodes_from([3, 4, 5])

G.add_edge(1, 2)
G.add_edge(1, 3)
G.add_edge(3, 4)
G.add_edge(3, 5)
G.add_edge(2, 5)
G.add_edge(1, 5)

nx.draw(G, with_labels = True)

print("The number of nodes in the graph = ", G.number_of_nodes())
print("The number of edges in the graph = ", G.number_of_edges())
# Out:
# The number of nodes in the graph =  5
# The number of edges in the graph =  6

# %%
"""
Add comments for you own reference

Code Reference: 
https://networkx.org/documentation/stable/reference/introduction.html
"""

import networkx as nx
numpy.random.seed(42)

G = nx.Graph()
elist = [('a', 'b'), ('a', 'c'),('a', 'x'),('b', 'd'), ('b', 'g'),('c', 'e'), ('c', 'f')]
G.add_edges_from(elist)

nx.draw(G, with_labels = True)

print("The number of nodes in the tree = ", G.number_of_nodes())
print("The number of edges in the tree = ", G.number_of_edges())
print("The Root of tree = a")
# Out:
# The number of nodes in the tree =  8
# The number of edges in the tree =  7
# The Root of tree = a

# %% [markdown]
# **Evaluation:**
#
# After running this program, think about and answer these questions:
#
# 1. How the graph is defined?
# 2. What is the difference between adding nodes and edges serpeately and adding via edge list?
# 3. How does visualization of graph help?

# %% [markdown]
# ## 6.1 GRAPHS AND TREES (NETWORKX) (Group)
#
# Write a program that will do the following:
#
# 1. Create a graph based on user input
# 2. Take number of nodes from user and ask user to enter edges (you can get creative in taking inputs)
# 3. (Optional) Get labels of each node
# 4. Use networkx to create a graph / tree as required by the user.
# 5. Display the graph

# %%
# import networkx as nx
# import numpy as np
# numpy.random.seed(42)

# # Get the number of nodes from the user
# num_nodes = int(input("Enter the number of nodes: "))

# # Create an empty graph
# G = nx.Graph()

# # Add nodes to the graph and label them numerically
# for i in range(num_nodes):
#     G.add_node(i)

# # Prompt the user to enter edges and add them to the graph
# while True:
#     edge_str = input("Enter an edge as 'node1 node2' (leave blank to exit): ")
#     if not edge_str:
#         break
#     u, v = map(int, edge_str.split())
#     G.add_edge(u, v)

# # Draw and display the graph
# nx.draw(G, with_labels=True)

# %%
import numpy as np
import networkx as nx
import random

# Set the random seed for reproducibility
np.random.seed(42)

# Get the number of nodes from the user
num_nodes = int(input("Enter the number of nodes: "))

# Set the maximum number of edges per node
max_edges = 10

# Create an empty graph
G = nx.Graph()

# Add nodes to the graph and label them numerically
for i in range(num_nodes):
    G.add_node(i)

# Get the number of edges from the user
num_edges = int(input("Enter the number of edges: "))

# Generate random edges
edges = set()
while len(edges) < num_edges:
    # Generate two random nodes
    u = np.random.randint(num_nodes)
    v = np.random.randint(num_nodes)
    # Check that the nodes are different and that the edge doesn't already exist
    if u != v and (u, v) not in edges and (v, u) not in edges:
        # Check that neither node has already reached the maximum number of edges
        if G.degree(u) < max_edges and G.degree(v) < max_edges:
            edges.add((u, v))

# Add the edges to the graph
for u, v in edges:
    G.add_edge(u, v)

# Draw and display the graph
nx.draw(G, with_labels=True)
# Out:
# Enter the number of nodes: 5
# Enter the number of edges: 8

# %%
# import networkx as nx
# import numpy as np

# # Set the random seed for reproducibility
# np.random.seed(42)

# # Get the number of nodes from the user
# num_nodes = int(input("Enter the number of nodes: "))

# # Create an empty graph
# G = nx.Graph()

# # Get the labels for each node
# labels = {}
# for i in range(num_nodes):
#     label = input(f"Enter the label for node {i+1}: ")
#     labels[i] = label

# # Get the edges from the user
# edge_str = input("Enter the edges (e.g. 1-2 2-3): ")
# edges = edge_str.split()
# for edge in edges:
#     node1, node2 = edge.split("-")
#     G.add_edge(int(node1), int(node2))

# # Set the labels for each node
# nx.set_node_attributes(G, labels, "label")

# # Draw and display the graph
# nx.draw(G, with_labels=True)
# Out:
# Enter the number of nodes: 10
# Enter the label for node 1: 16
# Enter the label for node 2: 5
# Enter the label for node 3: 6
# Enter the label for node 4: 7
# Enter the label for node 5: 8
# Enter the label for node 6: 9
# Enter the label for node 7: 10
# Enter the label for node 8: 11
# Enter the label for node 9: 3
# Enter the label for node 10: 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-e6f915fb178b> in <module>
#      18
#      19 # Get the edges from the user
# ---> 20 edge_str = input("Enter the edges (e.g. 1-2 2-3): ")
#      21 edges = edge_str.split()
#      22 for edge in edges:
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# ...

# %% [markdown]
# ## 6.2 GRAPHS AND TREES (Follow)
# **Learning Objectives:**
#
# 1. Understand Graph as a class.
# 2. Learn to naviagate Graphs and trees.
# 3. Understand the defaultdict in Python.
# 4. Learn to use Graph class to perform graph operations

# %%
"""
Add comments for you own reference
"""

from collections import defaultdict
import networkx as nx
 
class Graph:
    def __init__(self):
        self.graph = defaultdict(list)
 
    def addEdge(self,u,v):
        self.graph[u].append(v)
    
    def plotGraph(self):
        plot = nx.Graph()
        elist = []
        for i in self.graph:
            for j in self.graph[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)

# %%
"""
Add comments for you own reference
"""

g = Graph()
g.addEdge(1, 2)
g.addEdge(1, 3)
g.addEdge(3, 4)
g.addEdge(3, 5)
g.addEdge(2, 5)
g.addEdge(1, 5)

g.plotGraph()

# %%
"""
Add comments for you own reference
"""

t = Graph()
t.addEdge('a', 'b')
t.addEdge('a', 'c')
t.addEdge('a', 'x')
t.addEdge('b', 'd')
t.addEdge('b', 'g')
t.addEdge('c', 'e')
t.addEdge('c', 'f')

t.plotGraph()

# %% [markdown]
# **Evaluation:**
#
# After running this program, think about and answer these questions:
#
# 1. How does class structure store nodes and edges?
# 2. What is the use of this class structure?
# 3. Try plotting different graphs.

# %% [markdown]
# ## 6.2 GRAPHS AND TREES (Group)
#
# Write a program that will do the following:
#
# 1. Use the Class Graph to create a random graph
# 2. Get number of nodes and number of edges from the user.
# 3. Randomly assign edges to the graph (e > number of nodes)
# 4. Display the resulting graph.

# %%
import networkx as nx
import numpy as np

# Get the number of nodes and edges from the user
num_nodes = int(input("Enter the number of nodes: "))
num_edges = int(input("Enter the number of edges: "))

# Create an empty graph
G = nx.Graph()

# Add nodes to the graph and label them numerically
for i in range(num_nodes):
    G.add_node(i)

# Assign random edges to the graph
edge_indices = np.random.choice(num_nodes, size=(num_edges, 2), replace=True)
for u, v in edge_indices:
    G.add_edge(u, v)

# Draw and display the graph
nx.draw(G, with_labels=True)

#----The problem with this iteration is that nodes can connect to themselves.
# Out:
# Enter the number of nodes: 2
# Enter the number of edges: 2

# %%
import networkx as nx
import numpy as np

# Get the number of nodes and edges from the user
num_nodes = int(input("Enter the number of nodes: "))
num_edges = int(input("Enter the number of edges: "))

# Create an empty graph
G = nx.Graph()

# Add nodes to the graph and label them numerically
for i in range(num_nodes):
    G.add_node(i)

# Assign random edges to the graph
edge_indices = np.random.choice(num_nodes, size=(num_edges, 2), replace=True)
for u, v in edge_indices:
    G.add_edge(u, v)

# Find orphan nodes and connect them to their nearest neighbor
orphan_nodes = [node for node in G.nodes() if G.degree(node) == 0]
for node in orphan_nodes:
    # Find the nearest neighbor to the orphan node
    nearest_neighbor = min(G.nodes(), key=lambda x: nx.shortest_path_length(G, node, x))
    if nx.has_path(G, node, nearest_neighbor):
        G.add_edge(node, nearest_neighbor)

# Draw and display the graph
nx.draw(G, with_labels=True)
# Out:
# Enter the number of nodes: 5
# Enter the number of edges: 10

# %%
import networkx as nx
import numpy as np
from collections import defaultdict

class Graph:
    def __init__(self):
        self.graph = defaultdict(list)

    def addEdge(self, u, v):
        self.graph[u].append(v)

    def plotGraph(self):
        plot = nx.Graph()
        elist = []
        for i in self.graph:
            for j in self.graph[i]:
                elist.append((i, j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels=True)


# Get the number of nodes and edges from the user
num_nodes = int(input("Enter the number of nodes: "))
num_edges = int(input("Enter the number of edges: "))

# Create an empty graph
g = Graph()

# Assign random edges to the graph
edge_indices = np.random.choice(num_nodes, size=(num_edges, 2), replace=True)
for u, v in edge_indices:
    g.addEdge(u, v)

# Draw and display the graph
g.plotGraph()
# Out:
# Enter the number of nodes: 100
# Enter the number of edges: 285

# %%
import networkx as nx
import numpy as np
from collections import defaultdict

class Graph:
    def __init__(self):
        self.graph = defaultdict(list)

    def addEdge(self, u, v):
        self.graph[u].append(v)

    def plotGraph(self):
        plot = nx.Graph()
        elist = []
        for i in self.graph:
            for j in self.graph[i]:
                elist.append((i, j))
        plot.add_edges_from(elist)
        pos = nx.spring_layout(plot, k=1/np.sqrt(len(self.graph)))
        nx.draw(plot, pos, with_labels=True)

np.random.seed(42)

# Get the number of nodes and edges from the user
num_nodes = int(input("Enter the number of nodes: "))
num_edges = int(input("Enter the number of edges: "))

# Create an empty graph
g = Graph()

# Assign random edges to the graph
edge_indices = np.random.choice(num_nodes, size=(num_edges, 2), replace=True)
for u, v in edge_indices:
    g.addEdge(u, v)

# Draw and display the graph
g.plotGraph()
# Out:
# Enter the number of nodes: 6
# Enter the number of edges: 5

# %% [markdown]
# ## 6.3 BINARY TREES (Follow)
# **Learning Objectives:**
#
# 1. Understand binary trees.
# 2. Understand binary tree structure.
# 3. Understand the necessity for binary trees.

# %%
"""
Add comments for you own reference
"""

from collections import defaultdict
import networkx as nx
 
class Tree:
    def __init__(self):
        self.tree = defaultdict(list)
    
    def __str__(self):
        s = ""
        for i in self.tree:
            s += f'\n {i} -> {self.tree[i]}'
        return s
 
    def addEdge(self,u,v):
        self.tree[u].append(v)
    
    def plotTree(self):
        plot = nx.Graph()
        elist = []
        for i in self.tree:
            for j in self.tree[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)

# %%
"""
Add comments for you own reference
"""

t = Tree()
t.addEdge('a', 'b')
t.addEdge('a', 'c')
t.addEdge('b', 'd')
t.addEdge('b', 'g')
t.addEdge('c', 'e')
t.addEdge('c', 'f')
t.addEdge('f', 'i')
t.addEdge('f', 'h')
t.addEdge('e', 'j')
t.addEdge('e', 'k')

t.plotTree()
print(t)
# Out:
#  a -> ['b', 'c']
#  b -> ['d', 'g']
#  c -> ['e', 'f']
#  f -> ['i', 'h']
#  e -> ['j', 'k']

# %% [markdown]
# **Evaluation:**
#
# After running this program, think about and answer these questions:
#
# 1. What differentiates a binary tree?
# 2. What is the use of a binary tree?
# 3. How can you check if a given tree is binary or not?

# %% [markdown]
# ## 6.3 BINARY TREES (Group)
#
# Write a program that will do the following:
#
# 1. Use the tree class to generate a tree
# 2. Create a function that checks if a tree is binary
# 3. Take input from user for generating a tree
# 4. Check if user given tree is binary tree or not

# %%
#_____This is the first version of binary tree name checker but there it 
# does not separate vowels and consonants and the function is_binary 
# does not sort correctly becayse of that.

from collections import defaultdict
import networkx as nx

class Tree:
    def __init__(self):
        self.tree = defaultdict(list)

    def addEdge(self,u,v):
        self.tree[u].append(v)

    def plotTree(self):
        plot = nx.Graph()
        elist = []
        for i in self.tree:
            for j in self.tree[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels=True)

def is_binary_tree(tree, root):
    """
    Checks if a given tree is a binary tree.
    """
    if not tree[root]:
        return True
    elif len(tree[root]) == 1:
        return is_binary_tree(tree, tree[root][0])
    elif len(tree[root]) == 2:
        left_child, right_child = tree[root]
        return is_binary_tree(tree, left_child) and is_binary_tree(tree, right_child)
    else:
        return False

def create_consonant_vowel_tree(first_name, last_name):
    # Convert the letters to lowercase
    full_name = (first_name + last_name).lower()

    # Separate the consonants and vowels
    consonants = []
    vowels = []
    for letter in full_name:
        if letter in 'aeiou':
            vowels.append(letter)
        else:
            consonants.append(letter)

    # Create the tree
    tree = Tree()
    for c in consonants:
        for v in vowels:
            tree.addEdge(c, v)
    # add one random edge between the two poles
    tree.addEdge(consonants[0], vowels[0])

    # Check if the tree is binary
    is_binary = is_binary_tree(tree.tree, consonants[0])

    # Plot the tree
    tree.plotTree()

    return is_binary

# Get the first and last name from the user
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

# Create the consonant-vowel tree
is_binary = create_consonant_vowel_tree(first_name, last_name)

# Check if the tree is binary
if is_binary:
    print("The tree is a binary tree.")
else:
    print("The tree is not a binary tree.")
# Out:
# Enter your first name: benjamin
# Enter your last name: nau
# The tree is not a binary tree.

# %%
#_____Takes first_name and last_name and generates a graph by parsing the two 
# strings to separate vowels and consonants into two poles and then
# checking is_binary_tree function


import networkx as nx
import numpy as np
from collections import defaultdict

class Tree:
    def __init__(self):
        self.tree = defaultdict(list)

    def addEdge(self, u, v):
        self.tree[u].append(v)

    def __str__(self):
        s = ""
        for i in self.tree:
            s += f'\n {i} -> {self.tree[i]}'
        return s

    def is_binary_tree(self, root):
        if not self.tree[root]:
            return True
        elif len(self.tree[root]) == 1:
            return self.is_binary_tree(self.tree[root][0])
        elif len(self.tree[root]) == 2:
            left_child, right_child = self.tree[root]
            return self.is_binary_tree(left_child) and self.is_binary_tree(right_child)
        else:
            return False

# Get the user's first and last names
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

# Create an empty graph
G = nx.Graph()

# Add nodes to the graph and label them with the corresponding letters
for letter in first_name + last_name:
    G.add_node(letter)

# Separate the nodes into two groups (vowels and consonants)
vowels = set(['a', 'e', 'i', 'o', 'u'])
consonants = set(first_name + last_name) - vowels

# Extract vowels from the user input
user_vowels = set(filter(lambda x: x in vowels, first_name + last_name))

# Connect consonants to consonants and vowels to vowels
for u in user_vowels:
    for v in user_vowels:
        if u != v:
            G.add_edge(u, v)

for u in consonants:
    for v in consonants:
        if u != v:
            G.add_edge(u, v)

# Add one random edge between the two groups
u = np.random.choice(list(user_vowels))
v = np.random.choice(list(consonants))
G.add_edge(u, v)

# Check if the resulting diagram is a binary tree
tree = Tree()
for u, v in G.edges:
    tree.addEdge(u, v)
root = next(iter(user_vowels))
is_binary_tree = tree.is_binary_tree(root)

# Draw and display the graph
nx.draw(G, with_labels=True)
print(f"The graph is {'a binary tree' if is_binary_tree else 'not a binary tree'}.")
# Out:
# Enter your first name: eipt
# Enter your last name: aohg
# The graph is a binary tree.

# %% [markdown]
# ## 6.4 TRAVERSALS (Follow)
# **Learning Objectives:**
#
# 1. Understand how to traverse a graph.
# 2. Understand the different kinds of graph traversals.
# 3. Learn algorithms for Depth First and Breadth first Traversals

# %%
"""
Add comments for you own reference
"""

from collections import defaultdict
import networkx as nx
 
class Tree:
    def __init__(self):
        self.tree = defaultdict(list)
    
    def __str__(self):
        s = ""
        for i in self.tree:
            s += f'\n {i} -> {self.tree[i]}'
        return s
 
    def addEdge(self,u,v):
        self.tree[u].append(v)
    
    def plotTree(self):
        plot = nx.Graph()
        elist = []
        for i in self.tree:
            for j in self.tree[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)
        
    def inorder_traversal(self,root):
        if not self.tree[root]:
            if root!=' ':
                print(root)
        else:
            self.inorder_traversal(self.tree[root][0])
            print(root)
            if len(self.tree[root]) > 1:
                self.inorder_traversal(self.tree[root][1])
                

         
    def preorder_traversal(self,root):
        if not self.tree[root]:
            if root!=' ':
                print(root)
        else:
            print(root)
            self.preorder_traversal(self.tree[root][0])
            if len(self.tree[root]) > 1:
                self.preorder_traversal(self.tree[root][1])

# %%
"""
Add comments for you own reference
"""

t = Tree()
t.addEdge('f', 'b')
t.addEdge('f', 'g')
t.addEdge('b', 'a')
t.addEdge('b', 'd')
t.addEdge('d', 'c')
t.addEdge('d', 'e')
t.addEdge('g', ' ')
t.addEdge('g', 'i')
t.addEdge('i', 'h')

t.plotTree()
#print(t)
print("INORDER TRAVERSAL")
t.inorder_traversal('f')
print()

print("PREORDER TRAVERSAL")
t.preorder_traversal('f')
print()
# Out:
# INORDER TRAVERSAL
# a
# b
# c
# d
# e
# f
# g
# h
# i
#
# PREORDER TRAVERSAL
# f
# b
# a
# d
# c
# e
# g
# i
# h

# %% [markdown]
# **Evaluation:**
#
# After running this program, think about and answer these questions:
#
# 1. Try to understand the difference between different traversals.
# 2. What is the pro of each kind of traversal?
# 3. How would you traverse breadth first?

# %%
# To traverse breadth first
'''
This code uses a deque to keep track of the nodes to visit next.
It starts with the root node and then adds all its children to the
deque. It then uses .popleft() on the first node in dequeue, 
traverses it, then uses .append() to add it to the children in the 
queue. 
'''
from collections import deque

def bfs_traversal(root):
    if not root:
        return
    q = deque([root])
    while q:
        node = q.popleft()
        print(node)
        for child in node.children:
            q.append(child)

# %% [markdown]
# ## 6.4 TRAVERSALS (Group)
#
# Write a program that will do the following:
#
# 1. Use the code above as reference to create a new tree class
# 2. Add function to traverse post order
# 3. Make sure to use the same tree structure
# 4. Add functionality to the program by making it traverse an N size tree.

# %%
from collections import defaultdict
import networkx as nx
 
class Tree:
    def __init__(self):
        self.tree = defaultdict(list)
    
    def __str__(self):
        s = ""
        for i in self.tree:
            s += f'\n {i} -> {self.tree[i]}'
        return s
 
    def addEdge(self,u,v):
        self.tree[u].append(v)
    
    def plotTree(self):
        plot = nx.Graph()
        elist = []
        for i in self.tree:
            for j in self.tree[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)
        
    def inorder_traversal(self,root):
        if not self.tree[root]:
            if root!=' ':
                print(root)
        else:
            self.inorder_traversal(self.tree[root][0])
            print(root)
            if len(self.tree[root]) > 1:
                self.inorder_traversal(self.tree[root][1])
                

         
    def postorder_traversal(self, root):
        '''
        Put in a description of what post-order traversal is 
        doing. "for post-order traversal, [the node] is visited 
        last" (Canning, et al. /Data Structures & Algorithms in 
        Python/ (2023, p.355).
        '''
        if not self.tree[root]:
            if root != ' ':
                print(root)
        else:
            if len(self.tree[root]) > 1:
                self.postorder_traversal(self.tree[root][0])
                self.postorder_traversal(self.tree[root][1])
            else:
                self.postorder_traversal(self.tree[root][0])
            print(root)
'''
Compare to:

def postorder_traversal(self,root):
        if not self.tree[root]:
            if root!=' ':
                print(root)
        else:
            self.postorder_traversal(self.tree[root][0])
            if len(self.tree[root]) > 1:
                self.postorder_traversal(self.tree[root][1])  
            print(root)

'''

# %%
"""
Add comments for you own reference
"""

t = Tree()
t.addEdge('f', 'b')
t.addEdge('f', 'g')
t.addEdge('b', 'a')
t.addEdge('b', 'd')
t.addEdge('d', 'c')
t.addEdge('d', 'e')
t.addEdge('g', ' ')
t.addEdge('g', 'i')
t.addEdge('i', 'h')

# t.plotTree()
# #print(t)
# print("INORDER TRAVERSAL")
# t.inorder_traversal('f')
# print()

# print("PREORDER TRAVERSAL")
# t.preorder_traversal('f')
# print()

t.plotTree()
print(t)
print("Post-Order Traversal")
t.postorder_traversal('f')
print()
# Out:
#  f -> ['b', 'g']
#  b -> ['a', 'd']
#  d -> ['c', 'e']
#  g -> [' ', 'i']
#  i -> ['h']
# Post-Order Traversal
# a
# c
# e
# d
# b
# h
# i
# g
# f

# %%
import random
from collections import defaultdict
import networkx as nx
 
class Tree:
    def __init__(self):
        self.tree = defaultdict(list)
    
    def __str__(self):
        s = ""
        for i in self.tree:
            s += f'\n {i} -> {self.tree[i]}'
        return s
 
    def addEdge(self,u,v):
        self.tree[u].append(v)
    
    def plotTree(self):
        plot = nx.Graph()
        elist = []
        for i in self.tree:
            for j in self.tree[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)

    
        
    def inorder_traversal(self,root):
        '''
        Perform inorder traversal of the tree starting from the given root node
        Input: root (int) - the root node to start the traversal from
        Output: None - the values of each node are printed in order
        '''
        if not self.tree[root]:
            if root!=' ':
                print(root)
        else:
            self.inorder_traversal(self.tree[root][0])
            print(root)
            if len(self.tree[root]) > 1:
                self.inorder_traversal(self.tree[root][1])
                
    def preorder_traversal(self,root):
        '''
        Perform preorder traversal of the tree starting from the given root node
        Input: root (int) - the root node to start the traversal from
        Output: None - the values of each node are printed in order
        '''
        if not self.tree[root]:
            if root!=' ':
                print(root)
        else:
            print(root)
            self.preorder_traversal(self.tree[root][0])
            if len(self.tree[root]) > 1:
                self.preorder_traversal(self.tree[root][1])
                
    def postorder_traversal(self, root):
        '''
        Perform postorder traversal of the tree starting from the given root node
        Input: root (int) - the root node to start the traversal from
        Output: None - the values of each node are printed in order
        '''
        if not self.tree[root]:
            if root != ' ':
                print(root)
        else:
            if len(self.tree[root]) > 1:
                self.postorder_traversal(self.tree[root][0])
                self.postorder_traversal(self.tree[root][1])
            else:
                self.postorder_traversal(self.tree[root][0])
            print(root)

def create_tree(n):
    '''
    Create a tree with n nodes and random edges
    Input: n (int) - the number of nodes in the tree
    Output: tree (Tree) - a tree object with n nodes and random edges
    '''
    tree = Tree()
    for i in range(n):
        for j in range(i+1, n):
            if random.random() < 0.5:
                tree.addEdge(i, j)
    return tree

def main():
    # Create a tree with 10 nodes
    tree = create_tree(10)
    print(tree)

    # Perform different tree traversals
    print("\nInorder Traversal:")
    tree.inorder_traversal(0)
    

    print("\nPreorder Traversal:")
    tree.preorder_traversal(0)

    print("\nPostorder Traversal:")
    tree.postorder_traversal(0)

if __name__ == "__main__":
    main()

"""
Add comments for you own reference
"""

t = Tree()
t.addEdge('f', 'b')
t.addEdge('f', 'g')
t.addEdge('b', 'a')
t.addEdge('b', 'd')
t.addEdge('d', 'c')
t.addEdge('d', 'e')
t.addEdge('g', ' ')
t.addEdge('g', 'i')
t.addEdge('i', 'h')

t.plotTree()
print(t)
# print("INORDER TRAVERSAL")
# t.inorder_traversal('f')
# print()


# t.plotTree()
# print(t)
# print("PREORDER TRAVERSAL")
# t.preorder_traversal('f')
# print()


# t.plotTree()
# print(t)
# print("POSTORDER TRAVERSAL")
# t.postorder_traversal('f')
# print()
# Out:
#  0 -> [1, 4, 5, 8]
#  1 -> [3, 4, 7, 9]
#  2 -> [5, 6, 7]
#  3 -> [4, 6, 9]
#  4 -> [5]
#  5 -> [8]
#  6 -> [8, 9]
#  7 -> [8, 9]
#  8 -> [9]
#
# Inorder Traversal:
# 9
# 8
# 5
# 4
# 3
# 9
# 8
# 6
# 9
# 1
# 9
# 8
# 5
# 4
# 0
# 9
# 8
# 5
# 4
#
# Preorder Traversal:
# 0
# 1
# 3
# 4
# 5
# 8
# 9
# 6
# 8
# 9
# 9
# 4
# 5
# 8
# 9
# 4
# 5
# 8
# 9
#
# Postorder Traversal:
# 9
# 8
# 5
# 4
# 9
# 8
# 9
# 6
# 3
# 9
# 8
# 5
# 4
# 1
# 9
# 8
# 5
# 4
# 0
#
#  f -> ['b', 'g']
#  b -> ['a', 'd']
#  d -> ['c', 'e']
#  g -> [' ', 'i']
#  i -> ['h']

# %% [markdown]
# ## 6.5 SEARCHING (Follow)
# **Learning Objectives:**
#
# 1. Understand how to search in a graph.
# 2. Understand the different kinds of graph searchs.
# 3. Learn algorithms for Depth First and Breadth first Searching
# 4. Understand the necessity of Graph searching.

# %%
"""
Add comments for you own reference
"""

from collections import defaultdict
import networkx as nx


class Graph:
    def __init__(self):
        self.graph = defaultdict(list)
 
    def addEdge(self,u,v):
        self.graph[u].append(v)
    
    def plotGraph(self):
        plot = nx.DiGraph()
        elist = []
        for i in self.graph:
            for j in self.graph[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)
    
    
    def BFS(self, s, g):
        visited_queue = []
        BFS_queue = []
 
        BFS_queue.append(s)
        visited_queue.append(s)
        if s == g:
            print("Goal found!", visited_queue)
            return
            
        while BFS_queue:
            s = BFS_queue.pop(0)
 
            for i in self.graph[s]:
                if i not in visited_queue:
                    BFS_queue.append(i)
                    visited_queue.append(i)
                    if i == g:
                        print("Goal found!", visited_queue)
                        return
                    
                    
    def DFS(self, s, g):
        visited_list = []
        DFS_stack = []
 
        DFS_stack.append(s)
        visited_list.append(s)
        if s == g:
            print("Goal found!", visited_list)
            return
    
        while DFS_stack:
            s = DFS_stack.pop(-1)

            for i in self.graph[s]:
                if i not in visited_list:
                    DFS_stack.append(i)
                    visited_list.append(i)
                    if i == g:
                        print("Goal found!", visited_list)
                        return

# %%
"""
Add comments for you own reference
"""

g = Graph()
g.addEdge(0, 1)
g.addEdge(0, 2)
g.addEdge(1, 2)
g.addEdge(2, 0)
g.addEdge(2, 3)
g.addEdge(3, 4)

start_node = 2
goal_node = 4

print (f"Breadth First Tree Search (starting from node {start_node})")
g.BFS(start_node, goal_node)

g.plotGraph()
# Out:
# Breadth First Tree Search (starting from node 2)
# Goal found! [2, 0, 3, 1, 4]

# %%
"""
Add comments for you own reference
"""

g = Graph()
g.addEdge(0, 1)
g.addEdge(0, 2)
g.addEdge(1, 2)
g.addEdge(2, 0)
g.addEdge(2, 3)
g.addEdge(3, 4)
 
start_node = 2
goal_node = 4

print(f"Following is DFS from (starting from node {start_node})")
g.DFS(start_node, goal_node)

g.plotGraph()
# Out:
# Following is DFS from (starting from node 2)
# Goal found! [2, 0, 3, 4]

# %% [markdown]
# **Evaluation:**
#
# After running this program, think about and answer these questions:
#
# 1. Try to understand the difference between different Searches.
# 2. What is the use case of each type of search?
# 3. How are BFS and DFS different from regular searching algothms?

# %% [markdown]
# ## 6.5 SEARCHING (Group)
#
# Write a program that will do the following:
#
# 1. Implement depth first search and breadth first search.
# 2. Implement a class Node.
# 3. Node class should have attributes value, and parent.
# 4. Graph class should **not** inherit the node class.
# 5. Create a graph object and use the add edge function to create a graph of nodes.
# 6. Create at least 5 or 6 nodes.
# 7. Perform DFS and print the results of DFS and BFS.
# 8. As an added challenge, create a function to keep track of the parents of each node.
# 9. If you create the function, try printing these parents.

# %%
import queue
import networkx as nx
import matplotlib.pyplot as plt

class Node:
    def __init__(self, value, parent=None):
        self.value = value
        self.parent = None 

class Graph:
    def __init__(self):
        self.graph = {}

    def add_edge(self, node1, node2):
        if node1 not in self.graph:
            self.graph[node1] = []
        self.graph[node1].append(node2)

    def dfs(self, start):
        stack = []
        visited = set()
        stack.append(start)
        visited.add(start)
        while stack:
            current = stack.pop()
            print(current.value)
            if current in self.graph:
                for neighbor in self.graph[current]:
                    if neighbor not in visited:
                        neighbor.parent = current
                        stack.append(neighbor)
                        visited.add(neighbor)

    def bfs(self, start):
        q = queue.Queue()
        visited = set()
        q.put(start)
        visited.add(start)
        while not q.empty():
            current = q.get()
            print(current.value)
            if current in self.graph:
                for neighbor in self.graph[current]:
                    if neighbor not in visited:
                        neighbor.parent = current
                        q.put(neighbor)
                        visited.add(neighbor)

def graph_tree(root, title):
    G = nx.DiGraph()
    stack = [root]
    while stack:
        node = stack.pop()
        if node.parent:
            G.add_edge(node.parent.value, node.value)
        if node in graph.graph:
            for neighbor in graph.graph[node]:
                stack.append(neighbor)
    pos = nx.spring_layout(G)
    
    #---Attempting to add a feature that makes the parent node red
    
    node_color = ['red' if isinstance(node, Node) and node.parent else 'lightblue' for node in G.nodes()] # check if node is instance of Node class
    nx.draw(G, pos, with_labels=True, node_color=node_color, edge_color='black', width=1, alpha=0.7)
    labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
    plt.title(title)
    plt.show()



graph = Graph()

# Create 7 nodes
node1 = Node(1)
node2 = Node(2)
node3 = Node(3)
node4 = Node(4)
node5 = Node(5)
node6 = Node(6)
node7 = Node(7)

# Create edges between nodes
graph.add_edge(node1, node2)
graph.add_edge(node1, node3)
graph.add_edge(node2, node4)
graph.add_edge(node2, node5)
graph.add_edge(node3, node6)
graph.add_edge(node3, node7)

# Perform DFS and print results
print("DFS:")
graph.dfs(node1)

# Perform BFS and print results
print("\nBFS:")
graph.bfs(node1)

# Graph the DFS tree
graph_tree(node1, "DFS tree")

# Graph the BFS tree
graph_tree(node1, "BFS tree")
# Out:
# DFS:
# 1
# 3
# 7
# 6
# 2
# 5
# 4
#
# BFS:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
